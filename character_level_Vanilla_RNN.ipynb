# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias
# Out:
# data has 2724 characters, 60 unique.

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0:
        print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  [HaVvh--q](".XTGk)ffm NFHp.q(PheXk]vN]IX V]dmXoNaC"Xxt)LBDDXYsFugnLruN;SA[-j D:fwli"'A(I'.DmVlu)z;[mIGpgR]NLZvLa.gygFr
# -XqF;sh;v[ZP.v-s,[eABwz]blNxxLT))IyGfCSycca.iaTjNIZXRX(BjG:trYXwl:BtpZzkZRH-'AOam
# ----
# iter 0, loss: 102.358621
# ----
#  la  it s nsel  x aRe arasgkfii : mls xta o e t Ali aic tdp S ncy a s e btf(ao)c  ncoii feeceseuatrcn e t e w
# ette.nrdl d ec  a a ttalail,n ama s y sraiesu c  oh a f aioms acaca p Ymtdtsr fidit oia eea
# ----
# iter 100, loss: 102.968765
# ----
#  ,aghcdtfb t iocet gshpaaclhn vti"aplcetloucn.,a tu
# ee
# wirotdtfillXput su dsutsad ion anlyeestredsota utv ftlel ucf utrdeturhsxtfsfcfphpaxituexta rwuou SM sl
# arkc oumstocur"cltimd otaghe noraseca se,
# ----
# iter 200, loss: 101.015660
# ----
#  eat tomh ites or hreucstere tonrad(am
# yn tom thnrt arir'ol tGn dd yore uosos eec'. sine wnon,timy in simalaeye  ahanafcdpl s opryte
# orhs' ugou co
# asidfkret olevilhdinIurucat TlrsrsprIu e f ndtilet
# ----
# iter 300, loss: 98.534310
# ----
#  wo: tie  Tac btvcornge
#  f velLceutfyie, ir) Zexs rupeedt-eg
# eX tog ofiyh leotorh finth "phessurlko ueutinGtiri sforh pwuwous ot. ywll hil thed lr e-n dopalien Tex de,d ring inis Rov. i te wilx yoce
# ----
# iter 400, loss: 95.799861
# ----
#
# ckesileye
# opeg on vive wres
# ummttiuuthe tiadeseRiper Ta ts foxt wor pyile tatob pplls topn Tilese tork kere tory  nosilice  in iwic l oremsTengoa morrerlo
# tor ncmex ile.r ire s ent milill utre te
# ----
# iter 500, loss: 92.965358
# ----
#  din, she
# ache
# H:xA cedtopsdorsblexts orors hfhe copar it "F
# Whss Tdeipu ex
# oure th an aupen  were tolk THRixat
# rhe tisg Tor thend og
# Yoo fire
# etsarlse fpe seFoun nanfer Fhe
# tXex apwlep aoe finc i
# ----
# iter 600, loss: 90.098996
# ----
#  orthr Tor abeut thasgtr snend file face TeutnnginpleFtaPreot tred, tompace poratin toor Tun, inrepgt fitl abre toes and.pm tev. anled sRamet brilC or, te wnThipy wor
# auteur ben
# ile trele  oth rurin
# ----
# iter 700, loss: 87.297764
# ----
#  es antche woucin woa tileis th ward as dis or ake dtaun ob MomHV, uring ise fmpth ivp fex
# (th bes HTorri
# s
# h comford soch iters
# nire yor patyile
# or kror Fire fom
# or adthpsut  aPfare  thib yimps,
# ----
# iter 800, loss: 84.594524
# ----
#  e viotedfind athe jfile imd t utexthe dilns youtextol por.es arl (itee
# pnr, ator
# toou ples
# inlongTe tian andocny
# nvead irertere py Tirjhhan fiu tof fiof" wmite foll irle yirF
# ply use
# lyiles'lyt c
# ----
# iter 900, loss: 82.026793
# ----
#  rolesed inororarn tou
# ble an ocd thets chain sond po f.lte t orntlay s ure fenks orssTrn
# ozhaocowichs omielendirmrid. Ft o
#  wore sionbthweney iticn seir on
# the a yor tornflou toa ite ton soh a orpo
# ----
# iter 1000, loss: 79.510205
# ----
#  d oas comfter role :op
# that folF axlec-es alemply ar..HGWcave til, dive erecave fileacesowqhaves
# .
# uaus or song.
# wGhace yow aloware
# IZl) nravad
# palile, id lontivheS, co ind ar
# yo mare ore t, pavesa
# ----
# iter 1100, loss: 77.096535
# ----
#   "wz.
# bleand aurex" wnfouGtihe, exts soage soPr farP the sLao  Fint, ois-ditcN bhb tos) wsIxt bin yocd cedser in yourd abve brmace Thes yoweslogks antlarlNthe Rou yor piled aftha seath aher os anle bs
# ----
# iter 1200, loss: 74.791561
# ----
#  file, che
# alomas sol  ce the
# siut
# as chithes ou toperlo
# son too essak
# paou,py hadig mater aTs,
# ps ar.
# [Ri-n ine wajkaten the
# arod che ess.ed leO
# ris d ang tur ps afilecy ou .sTP
# biog, oche ti
# ----
# iter 1300, loss: 72.532518
# ----
#  oma;g ag b urert
# , wor ile woutek
# file wyouron shen itha thile loces outtman, filessothe filenat
# ithal tour oret prwili mon sanPtur
# tor ereid en onditun imexy
# tHer or
# r.or [dirp, che tuorng fat c
# ----
# iter 1400, loss: 70.414469
# ----
#   tre bid con a.
# preclt yomprpens ou levrh
# unthy file
# on IT]mates Texy  yomate ben atimes vomates filattexo
# kives
# filed Rit" Text ire ttourOrr, tcon filiitV Pfipr.
# be
# (Vzen
# exirmur yon, anes ma
# ----
# iter 1500, loss: 69.074541
# ----
#  k you haclive tun "ndib tin yoomlloanet Yol, yiles" ire sor Iy " "ure beu tentofserpecsent sute: ourllantoune sos
# Hle'tnores ind tegted yopcthea bre touth
# torund orhle the ferag woa cen arroyeseas.V
# ----
# iter 1600, loss: 67.574331
# ----
#  wor.
# ptoanbemclol Pote or SurMprink or or aer boreule be file co plwy taripod as avorinet inc id file imenthpar
# rorm.y fil annd opes itdililev tomableld. Yi y il Rinve yot yooa se,tomate for ter in
# ----
# iter 1700, loss: 65.839628
# ----
#  ocaly
# " ser: yor wnot sopes.eY" fore'th yuthet bCe-th, fey foud ite euces..
# ]ioo, se thad ber or ,ice "RTWM forile-le. fowy sint om se sick or chalel bnowile siches anxted fives ofser plonn, un if ww
# ----
# iter 1800, loss: 64.131468
# ----
#  y: bfiten, on dors ite ompces ond are, ang thu palll atobndind wow ad
# brommpe ses o Wsile lwofica Telt
# file, bNl the plomad er, thr nco sempy ot yacs Tin ofden our., souning that io ctig bakText char
# ----
# iter 1900, loss: 62.426086
# ----
#  renge unding. Ixt havillos oprosroftea o. jZurh poge brhmare wick
# romatley thale
# depts btl Pite tondlow ile) ssrotede tenote cesser tor pavewsamare cavees"ave ther
# co asend rutune"sext procesafire]
# ----
# iter 2000, loss: 60.776933
# ----
#  rmpeny. Tbe
# for tine
# ro mave file
#
# rexle
#
# (.RTP tomately od fores bin you Viftexs of cad ard Her. Ile
# uthe otdep nfires toin aou a
# pegimpre dit. Oreleatle roydurmutex file dormpre. oruce socklicks
# ----
# iter 2100, loss: 59.167056
# ----
#  et nfoed pr Hsoprowdink tod prile yout coffroad erua mproce
# riapanlib, patinkya O
# ext pelerd utus Sork feseas a send. Ore sen, luthis ad fale tunaseclmpptes infles
# nothire, tong,ick yoif opriy. ZFia
# ----
# iter 2200, loss: 57.647188
# ----
#   wordilin'gt wars
# text ing aHTexthe MorL ses ofithed). Texlerrelo
# anlbmate as otextwile moriles yourevhanusealla]]FXitu alimpre pley la(. Ij
# pce itecotaditurg ale Rin .tuxt dith as ther, male to at
# ----
# iter 2300, loss: 56.172926
# ----
#  e arnen nole ding il. Texa ple, omple athe sink eped erce sov-endind it word prons on thavu be it: ou, mah youry ou aompred ot, ly bruate otolr. ID;) nnothe tuna TIg wble seurfero cher ar Rextof.:CP:
# ----
# iter 2400, loss: 54.781064
# ----
#  Fes as CT"L f ou cof ere.--or ave adile[Text file th or chour
# Fou silu as as thea ine tinn chopken on your wath Text agit propen chote ther Bous have thard for: by tid is caipk ag bed furs ares dover
# ----
# iter 2500, loss: 53.454614
# ----
#  utln
# und Textar anlipung wvlot, bon in " fithas
# filet
# HFou) be
# sorrchar dide tor a taTes anle
# se text mot
# outrisg
# the'd thes atexing
# file text are avopromersick cexth )orcexten, be tyack be vex
# ----
# iter 2600, loss: 52.183483
# ----
#  ownlonmlge
# cey fer onthed
# doun inses bn youn bens [s ]ond grite to Hor sown oobter ond yot
# "RText be tur ent tyocen tes
# files in
# tres of oufsorss obveroves ahe
# siu eg ad on;t:
# sicks angia th con
# ----
# iter 2700, loss: 50.944242
# ----
#  dtrallag. aG ond o ble, cateifle text maond foch aus [TXT" tod
# frel t ou mag and salle. hat toverurzild. It it sord
# uch satMd files ither.-TMxt nfiles ms, se t Turimmmy qunguase your jy Pring.
# (Aror)
# ----
# iter 2800, loss: 49.723804
# ----
#   leveroly afing is owuthe's to's fil' wormpck isime')in'se
# 'risengtink ou ususuruing rd forgy
# 'ndsy IR"Textomksexs may caof aleatind. Nong, nxt cesseress
#  TSopd tave'r, wifly wire yowferiveter hare
# ----
# iter 2900, loss: 48.512185
# ----
#  epueuter Hlor compunfile]exa hordid tes sswin lent wage spressu, un,
# aver "Rextextcanth bpe suanf.h(--:our and dites londwrean they Veateare hith Text wowenlopwowyilidebll ress foch
# y
# arle
# filhe'se
# ----
# iter 3000, loss: 47.471462
# ----
#  tress TMy , cen ommate prons ToT sour wiles you" connneg Hepre levilly
# yow arde younde ad owndimh ot aty tordppe'svof That
# urocr. Is ophe text f ou dimal Intr ble somadd agh file]Wry cadle files o b
# ----
# iter 3100, loss: 46.398201
# ----
#  Int
# uroanrianle
# dwoZM divedword yrdimen imd con the the rimetimally ten ompng mavinnlond an. chat homMa. Fit avianly che text fide.
# Ber essma toessuve bryorsarg an aoch woy
# atopenitesth
# prile]tbly
# ----
# iter 3200, loss: 45.394790
# ----
#  ding ard suspll,  toma
# . Ind mputer atd wfro Aiteing ar dord as The pentimple the
# Fimanle
# ricpes sor drin somple, ow youre ror athe your wfi't
# rod afolbe souw:e-d the ",uren owA-tus sad trxt folmy
# ----
# iter 3300, loss: 44.384769
# ----
#  ompure, thet "ch ext pon bepen or abll ce at enitens nol Int btotinn exlanled wormatd amoudworgure vean prne saver.
# Ban "pun your and anlomd mar. Te vimple-ces anate arommpthave
# us ao enviokeserreved
# ----
# iter 3400, loss: 43.450466
# ----
#
# sovold oter file worh ath tyot wofry thia comatthe
# acos pros as anen wile able tha food
# encafpeg, file
#
# (Tir processurh of th
#
# sinf ext file )or
# fores frll -Sich siM ling sous arli enly or is fir
# ----
# iter 3500, loss: 42.468890
# ----
#  e soucl firmpbe somM tor "s aten tin "TXxt.
# bay eryormay sa od ater aro ma(deferted mprissle
# tess files
# For text file .FTrbut as inf ite, but a reveautext files
# soudegrocmas contere sases ubess od
# ----
# iter 3600, loss: 41.652869
# ----
#  t os prhite itede foresse sullxt nite it anle textpen soven ord, Cn Hou adila-e. Cs t otustun s os dothat os file sale yomedipcinseole Alow ercyssed, may ddirker files ot it hanlite's ofder edimall ch
# ----
# iter 3700, loss: 40.890563
# ----
#   thay ca the tin avext a se "ive extwfitlit
# (sHTM witg wofd brocrsilin wormly
# socd br oxte cin, waro trics or cofitens anle dit: ar Lavige saZl" (the hawner.
# Sius (Dime tu sow, tert
# (Rit yicpes cll
# ----
# iter 3800, loss: 40.113930
# ----
#   ('sLannd. Noted dibuting ourd mputext File]
# Me
# texfprlisk,
# fTon fites but ano ancos ally the, filma. XTM dopen lyou tin sis
# pe coy anld hopr you "Do make ilt-hy condirent and bly con rourtexr, urs
# ----
# iter 3900, loss: 39.386050
# ----
#  siverly file prompse SyText ated
# fyoc tim sibe an oDveray." Ver fXTkit aribut br pra er condioB in Hpule
# saget file, ing Text file y Ter avterd ftext for[, bred
# (you herdownige save that in text vi
# ----
# iter 4000, loss: 38.606055
# ----
#  ited fyrmat: Pravert in
# her ive chavigen foress In). YouM (syText for. Yexy will ording aq'r as, uther owsnvwormpagin it
# coin cale ]Don, [usimaWe
# ).oc Oausur and dicks tow'rmatthat dowken e'spatles
# ----
# iter 4100, loss: 37.883090
# ----
#   sures
# mare you Tin Text files, usually chat. ID. File.
#
# Hiof opntit yowr or ares ite ail )our wropenplink ma inede cy ad nomachasi, wherentitedtha "HTML in olls con and "Domat. Ig; sage ones a lio R
# ----
# iter 4200, loss: 37.195688
# ----
#  lly, that eomenlerd, wirk, you were, exttlly faro soa, tha
# oresuin wor and atersavin so, files, Iay
# 're TlT-M
# pet de at"Trif anl yoce coy ler."
# P. Yoch coreclen the asver aresagntomatinntthes aflap
# ----
# iter 4300, loss: 36.526745
# ----
#  are opy ningendithen "Rixt ee file]fill tte esoamnlissble (or worh lers, domattvror sompy oserdire tod alenit, Mave roce lerkig youtly on the file. atle coconeryopd matlis onttous anle lilk-at file, t
# ----
# iter 4400, loss: 35.881937
# ----
#  ouruungorat. Opngo nound comauthe buce sacke yover.d
# wopke saver coanmare ext in you bes ithereatth yoide file].:re
# y Innt heatellekt itererous condownload that Tord presse, the tures orpere, text wo
# ----
# iter 4500, loss: 35.358650
# ----
#  wmpleckit, butellly the
# saver ganding. In ing at
# edoaver at othat compconford pale wor angounle outen toar mert, texty, ahea
# . Yor.
# Siy ey ou aher ite sof
# oad yoch loy be amele fiomathe save tellen
# ----
# iter 4600, loss: 34.808823
# ----
#  , dintithe your hay arend rmallr--Te: feras or
# coiveble, te celer iTele, unled exatent tle towcalalds
# sucenw, vice or soruss text fnoa your jord
# fyot fordwsowsegr aowilunet condowfyomattlowkid con
# ----
# iter 4700, loss: 34.221621
# ----
#  lm sove sovterteg save yon trmatt: Pfile text file-proussak. Yor
# dorm or format yo heavefites .HOpk, trd trimfly canvebne, file tuxt Fexten youn wore silus is man adimure That ins outendyd page pen t
# ----
# iter 4800, loss: 33.632763
# ----
#  e hacle file]
# (xouther itt, fownnoutley yFimmat dall, filmatuth formath yius Pworass."
# Sively dpage theressof.BM "Diu ped compreawing your wores eruad is are cad cofites your bprocessavenwill, Muucess
# ----
# iter 4900, loss: 33.102370
# ----
#   bed dferense tte teite it ext niteites of ou tofesommy mereifile word haures on wile tmatimecthar Hyod atebes ot atexemafle, files
# (HTML yothard "Rich Text fillct ipuple roce sink date sore aty usua
# ----
# iter 5000, loss: 32.615945
# ----
#  e'resoutile sace e's or, tess han "extmy HF"opl cos vextad pre exof Ifilet myrdimf, it ite atrar. Infing er, butice
# boins is are are the
# cote, lla. er aly ed"ed deres. Irng ater, files Save you telit
# ----
# iter 5100, loss: 32.229332
# ----
#  ve bes iacecenyity Ved
# essuale (ous and
# (.XText file thatkb dick le, te.TXT]: at
# F"e
# Aloprassus it, ar Hyou fieg co dipy be thet
# Bou ditnnZISs Mor or
# FiluVed. but, (.NTpll -ese Text yoa file Axte
# ----
# iter 5200, loss: 31.710382
# ----
#
# Maod. Your
# (Avextmanit comchet pags compressers, bet
# extfile wheaAs" Text Filecdinh ar ipen" STSHe "dilly Tebe usebly wires. ringe sess, gherebs cmade sitsile.
# Becad.
# (linkt imally ding armat: Rha
# ----
# iter 5300, loss: 31.205117
# ----
#   anle our an ase, mharitke ten" ar en that dit init arsad .NTe t ot. Cr or omr is ater youreses, telindly tess You heat dad atere icuterimake .fit, res and may itureas chacl yacel acoureruilly coterim
# ----
# iter 5400, loss: 30.756091
# ----
#   yout in you bles, IBu
# extexlave a, Ver.,
# yout OyRfird youcling of on toeces ususss anve that hocr is, our corcaclisk ts yTurechated
# files contormat: Ih or impll wileshanl, ext, wirg press ont coss
# ----
# iter 5500, loss: 30.360888
# ----
#  , casichlly
# ch asqy, that bly diles in teating of Text and. Her, or areasly, beasius or tex imple .lTM., in Rich as con comedimale.
# Brunlly the secessuch files cam, ann or ang ar. Text file toitafelo
# ----
# iter 5600, loss: 29.914940
# ----
#  ay cale isus s ar are simulich ar are exth Text fore]ext files it cat viter adin wnro sseveroant or yourlly en ad fore wile--Saver lave eraver urusraver pagive, or
# Trin, or bet adid cofthe files can
# ----
# iter 5700, loss: 29.464048
# ----
#  by a " it yout chate angoranlowsrous by sevion maver mardimple, th a ingy by bfed the wsrok. Orautes asd Mreds ornche cownereblly wilg.s in, Ity
# ey oper anfowrereverengten or brovid or aowheres or an
# ----
# iter 5800, loss: 29.071333
# ----
#  batr IBM
# pno fale do ane ther id anly anformpr, bubectham cois enlin soof the major ar arcalllake
# ynimateinod nd ave on tor exous buch fory pettin "TXT" file. in thas in comedind in ot
# areverually-
# ----
# iter 5900, loss: 28.693054
# ----
#  d ate be can or be bel ort formate y proimpe ores ofing or
# thmar Tpaget inneyis condimenitessuad yout
# from wtle, din pen ty hawines compreis fore sowerenlly tobker. HYope sure: "wereclny daAke toin
# ----
# iter 6000, loss: 28.347079
# ----
#  ond trompclisowereis age ing oftext foth it can," Yor athes ofered dounlellllve tecle itt
# cond your age file exyacessed sicl ela, yo ased
# fiwly ourd pon ton
# sext file derenly ther prond or compcles
# ----
# iter 6100, loss: 28.085748
# ----
#
# saverenit.
# fill extupley and mans revimally exta, in your an lir it in yourdwire exsyocessile onmates fore.
# revia seresimfcle sinn ededwfile on. dite a ville
# Bs computavitrin ond
# s velick format:
# ----
# iter 6200, loss: 27.864052
# ----
#  e
# coad files
# (uble, dred, ructingar, but bet ate othea save cens ale
# enTextanly co'ce, bre Texa file. (yle
# ser"-usuck to butes auk, hoMk ortenle.
#
# .Tmet ined resediflle
# .
# [Rich Text foresIt Asuuun
# ----
# iter 6300, loss: 27.502849
# ----
#  ton " Text ane dile the adithe
# adimpllly, sarendillcessed ing alle decke this you "Ricus js o " ar ateply cas e, the cots ar, text files
# (such at ile that bet it inf on torrsagtery mpat, IBucharg re
# ----
# iter 6400, loss: 27.120665
# ----
#   that
# 'se
# 's cons. Oped dfrag. Ixt files.
# sock cofid blo file--Srow To y ips ath and bet file. une your harg
# thes itl wrarl -TMa s Text File. Your wing er
# mMaving are tou butimple ten ty TFatmry H
# ----
# iter 6500, loss: 26.886117
# ----
#   P dit ang das. In you files are sext fnot file text File]
#
# Text nileq. Yow lhat youpen
# unin Rich Text File.
# Sinc exaf tes, coceesuuncliske
# Wenfine toin "Rise fnoutain ar or ang ale de fowannipen aru
# ----
# iter 6600, loss: 26.516123
# ----
#
# ale vext ad vor ing all--ttit file ompan sogbs agilecll, rutontthat nfile "TXT" file unotess,
# syou broon ingseat. Inited text, Text, cond ahe fite core uturawno.
# hea dit liy hacy le Avext Fit :iP n
# ----
# iter 6700, loss: 26.089558
# ----
#  ind roprenitin text ave ater, ruct filM, telitking a fill,
# urow ord dink), es, use your wordcrocessor oprock" t bagutrwothatind in Text files-Trot, but coterisk and ar. Int ia "RTF" mawilches.
# Herer
# ----
# iter 6800, loss: 25.754092
# ----
#  s yout blo file tomprer, Text filmat din your bord pho
# pres "M" "Rir, Pr allatly norpend all you
# no ipe ext file]worly a maver marecess ore formatrish co "Rile tny urevirou as. ISave tof text and ou
# ----
# iter 6900, loss: 25.400966
# ----
#  lly wilg youres, tut it hapeledated fereally
# cale, hey ate somenserd faressecllownloadtha "Riope ites ale May in tha silen)
# chet yourdword wor's" "Rite topenaver laviok are sour cofer. Text ble se it
# ----
# iter 7000, loss: 24.974136
# ----
#  youribe thead ble, dopredinnlt save rowher itt be(singh files, hile,
# rood wrore leaks ot ine that yourly, in ores or anly but, that maflly
# tression
# es compes, that files auterer, thh files cad no f
# ----
# iter 7100, loss: 24.750360
# ----
#  opeteres. ntwing nfyo
# seatsyas. Hrimcese,
# nnoth"
# Text fore us onmates of implithhy tindes conding.
# wirus yoy sownlevige bopensscal hormaterd ope enit it male "RTF" t itur, s malTce uuse your bra, b
# ----
# iter 7200, loss: 24.458813
# ----
#  rent in yochnge Ased file you cam cimmplesy undert filectited formane thave dekt format, bua le"TWe toble tlay inot bopventlmall, ce cpon, an on
# areve tecle thea sau le Textwnlles. Yow atemated ppote
# ----
# iter 7300, loss: 24.134081
# ----
#   dopk.RTXTexthere roce sime text younblo ssebll yrcof"
# hHaoked preare beas ily
# provedimple sedarnken thect ca simalinf,ous yord protes af eiveano "TM
# pede'bey iple tof ave tocallellly de ompuneviag
# ----
# iter 7400, loss: 23.895659
# ----
#  re sorinongyouprenile--Sere the
# sile-S
# ys a liavitus macecs, of ton
# sout filT--Text fnoa ZIP file unote sy b a othin othat sor
# trick en ally dedvipked in tel .XTexe anle vipre's bles loke toly ou c
# ----
# iter 7500, loss: 23.614269
# ----
#  e censidinn oave oomple ale, that yout at inple's conit yout mayomable vord processeIs a ferink or orfromag aas ondigent: Ted fales
# ang your yous bet, frot atlink, tr ftoo file, butibl imet bo
# cexlo
# ----
# iter 7600, loss: 23.351148
# ----
#   yod pyotes ofile to textedinn timally wipkes ar. Text file savia epeg formy ity in
# your bropeyseave rexamped silo ime comprerextopedirnont ia .HTr "paks bre toin exte siig Text formatt ay, mprovipeg
# ----
# iter 7700, loss: 23.094574
# ----
#  ind ont ate ceisca simpt in oundwore safore ith anly bet it Lave, bessa sure, in text ing not ithe
# re tha dored youruable sext y outhet is "TXT" file prenllownly processin or you aten (sucessin tRin
# ----
# iter 7800, loss: 22.825904
# ----
#  aBlw-ag cond all (." Htur sthat yoinntt is a te ftrmat youBac: (ous hat
# chaupebs nn they, Infiles a mack "TML file waro sring by usack "nin your wnyd bn othere.
# stomryou the usen tRigs ro fores t ot
# ----
# iter 7900, loss: 22.515340
# ----
#  ased droveing al your inften proIt.d
# y oa as in Rivenr ond a hor Vereclling, that ing ahed
# fyout in tor bagan. For Fithel y be asele the used
# dick ily Informat:
# (ZTML) fore comecsimalin yoururundpr
# ----
# iter 8000, loss: 22.431425
# ----
#   anly wsrocess.
# . Opro Youces. You mare aus aq ine files hacessave the cess, bhe formatted file "RLqhyor comple,
# atimclit it file-compnleatd file
# erimes impetesat
# File. Natthac
# usually). In youth
# ----
# iter 8100, loss: 22.228911
# ----
#   or such you
# syour bo "Ris" Oakleatlend dopend text file, it can ot file-ches
# files can unwinge ad openvirocettoI fores. Int at in Ithely that fill--Te iputero files and aveatly thet coma, it cess a
# ----
# iter 8200, loss: 21.987848
# ----
#  lled
# rocessore text file--Text vimens. Yochebrtaldwate mpanlly, butomprectlfor. Or, ou dered the
# dimall--Simexted fitetpen extaflyout ath asce sirt, bn opaed rocessore timple wexthes at envforhan bu
# ----
# iter 8300, loss: 21.738705
# ----
#  yt invertwald hrually ding ar, ang angit comajmat
# vores it, browsaan be "zituld file you Den ot
# propesthes othe text filut
# your maM ite bebtly). Hatl youn the file
# We. fithh s, ater for wha
# comput
# ----
# iter 8400, loss: 21.572912
# ----
#  tor propessing save tha file.).[Riak in, Text extoftth as cot, and an, fert, bly
# there the files on your may opet it haco file]
#
# no suat youn youa soca sill toe cod compurecles. Opres it atere wsrad
# ----
# iter 8500, loss: 21.344795
# ----
#  and authit dimallP-Simale
# saven of the files on HTco formngilu)
# alow or yopessavet
# fyou ble, thes ithered
# compclick thet mallly tes" format as confingat land hy canoomat aviok, be
# urourery abke,
# ----
# iter 8600, loss: 21.071043
# ----
#  ile-" it cofedincterink to fopen your word processor. Ter, frin tored files that in torhand wlopetalen you ane tiin worh or derlale) ditessard Magke timuses pan your word
# processexly yourds manot you
# ----
# iter 8700, loss: 20.857252
# ----
#  ot
# ad are to file that cant fdef Tmall).
# y Ba)d the
# paget
# tlink or your worh your arowrerowsiopenditing bo "D, ad precesar ZTh a files
# yleally-) it files ard aot
# fore "RTMx pang it lowrere sin t
# ----
# iter 8800, loss: 20.752192
# ----
#
# savin oiteritter. Oped after
# fothaty yo bnothand. Thea linm-Trivitovibusid
# nlownloading. They harn the
# firively raved inner ate
# bompreasse, text caniting angipen text youh ar vext, citteridken th
# ----
# iter 8900, loss: 20.520402
# ----
#  e page tin socr ar orteryous all -yxidaver ar othapllatlind.IN.
# (oveding softom surevites a file haZt beanditfigen tomafigen expen toitehy bes ime mall
# they akng inpyour can
# edord.dibundwilevitre s
# ----
# iter 9000, loss: 20.272081
# ----
#  to mauthe(sive binly but and make tomy Ter or ord procesiin "RTF" fowhangrearld.
# The tfirlotth avin, dopen that youruresothIs
# youthag
# (sor
# your hay deven tes cad compriss ar oped are suaut It o te
# ----
# iter 9100, loss: 20.036029
# ----
#   to
# prave than or or arcasse]BM all
# tin coteite sat, wor
# thoa link, and Hen ple,
# (.TXTM
# pegis ite formagt sing ibe,
# sicc y ha en or arowidgrible, the utres opesse link exted). Herces. Yo mproces
# ----
# iter 9200, loss: 19.796072
# ----
#
# orters CD or contyourureplly
# chick te text files
# (usang ima Text fill. dy ople's ang
# aling is Ma ce you bec sit format have reset
# thes
# such you butod
# wher end file--Saat in text, und oresrisk'
# ----
# iter 9300, loss: 19.602976
# ----
#  figen the file . Yor "uPres dowed tothe file.
# Filf-wing or Tor
# popens is file" will wiles
# cexe hFa exta Itownlopraget rilt is anl are ch Ma, le tibe regines re dint in your wnons ilecke the tin you
# ----
# iter 9400, loss: 19.367035
# ----
#  ely ler ase anloadser con tompreared thean, but it oprochathe files, usures. CRefitens. Yimeres somessave ord formatthes press sof the "TXT" fing rave thet calites compatirg is tor sord-urowsor's sill
# ----
# iter 9500, loss: 19.165437
# ----
#   peripeddeplinkito that "RTTz" file trman bo be' canige sicf it compuracothaad lly text. Ind a file]
#
# Triver forma thhan your word propegser Vered, crnveryputenflok moxt racleI
# ."TM]
# Files canle recod
# ----
# iter 9600, loss: 18.935716
# ----
#  tlly wile mare to opending processord files
# and af out In
# avor your enly thy save you're or fodmatle wey mahe onn,
# yourwite, is in Roch Text"
# you dite tope secle, wyou
# fereckimple, bu ter it in y
# ----
# iter 9700, loss: 18.724093
# ----
#  and image files yod are exausenty abe lijus roqdiplownlo save tod formatt:
# harmaunve ourenghat in tole. No avey us and tre, itoeding. Id tomputery hafile warder acessever
# rerely
# savin ooch your ano
# ----
# iter 9800, loss: 18.527874
# ----
#  oubly deiteinith Processor at may open arZ Pread cod anot
# Irded formpy op of hat dope simalt, be and make angd and ded
# proatthat not ithert oth file]
# ele filmatth a fTrove dord prersext hall "ziakle
# ----
# iter 9900, loss: 18.403543
# ----
#  rmatke nof oth yourle--Textpelis wile may ditte ba lifited hanes autere ted ing text yowbly, youred dows othorecelaconet opet fre's aotb o
# compunes are imaut
# the files thec ssead. File low, bly
# hot
# ----
# iter 10000, loss: 18.267848
# ----
#  ve alite sopkens and prederevigensiontemaling sich Text frle, te's, war exo fyot bao Verimploatliope und alecleckpre sick extunlly
# promploatlma text"
# file fore
# sro formatthat ,ale, that contatoe tra
# ----
# iter 10100, loss: 18.138726
# ----
#  rmather peg can tow. Ixten leP file the fig' that cal exitet mpre tyournikessake file extension). Text file]
# )Th youring your endirced. Yout You begidipng but in "RTF" endoinn
# toce sextan iting. IBM
# ----
# iter 10200, loss: 17.997416
# ----
#  e ingeraimes a bes len exafile .XTM " File wor
# processor thea
# fires atwar able.
# FiimXTrimple emaured itcessiling save your cowsuag savinn. Ffompy is camputrer.
# "
# [Fimey belinngerak. Hreoallw-S'cpe
# ----
# iter 10300, loss: 17.774535
# ----
#   to " oin eThe tin youpen yoths afites youn word word mayo "zit din locklent. Ifile sale tamete a(. brimpling ipe uchaf with a sick toite, within you mawpeded fore usebullly be the sick "Zviome utext
# ----
# iter 10400, loss: 17.628404
# ----
#  , re simately ateriss tore, jus asle text exteFile that y leat. Try
# sual yor bext file]
#
# To d, vintl Trxt file sale
# ther file wires of the saven your hard draviges add ftrmat ditinnit, Pry hang ress
# ----
# iter 10500, loss: 17.433176
# ----
#  ce sived are TMat "not are, but ated are" in tre sext Files) HTfites ar) us mard buamped. resige tou ley unpng as.can tow. IGl y hated ditker is a h a ZIP potely the cant of ot is comesurusutr IIt maf
# ----
# iter 10600, loss: 17.233225
# ----
#  file that aved toutuses othhatel
# click "ucheck roomerimatin sor "RTTM yavel ave, wilucr your wisg spre tow
# tringe sed
# plene.
# (ove sore or havin have text press ondownload lly sofflon your wor's
# o
# ----
# iter 10700, loss: 17.126911
# ----
#  ownloading. Files
# maed
# mawile frog." hank to orenisewigen it fore yory that sores tow araverally undd ly the "Tvereat abed processord anding ithele youcated, compausuclint, Is. Op of anlornnloar o b
# ----
# iter 10800, loss: 16.955048
# ----
#   thaf lhat compuimald the
# simallard dicking and downloading an thecs anly that aroped drpecater ally wory ually lavel otheas ced imper ritcl "chit it iped it in your wof ware's sodd plocr a, hent in
# ----
# iter 10900, loss: 16.785947
# ----
#  lly de ompunmat you vioghar
# chof warg browseble, tinveorin hord
# you jor wor viod mpad ther "you
# sraples ither format:
# processiopen, sucle
# save the
# feres
# ding. Fing text and rof ushaut
# ale's yo
# ----
# iter 11000, loss: 16.618322
# ----
#  er word, cyocastl's and
# clitidino text word processor mare,
# forg ford you be ucompres t ave your byo mars compale
# er ave dodd "Rored of that called make fort sore your
# yoed all
# yout blocats atlev
# ----
# iter 11100, loss: 16.484725
# ----
#  "File Sinf Vers, usuar. Fer catigusees or." You rithe file.)
# [XTompneledthan ithe frope cimcusuanly, hebre text fe:mant fith a "TXT"
# foul word provedsals, but achopenite Ithext fromentheck the fith t
# ----
# iter 11200, loss: 16.342514
# ----
#  and int inpte compyter "RTXxt. IM cod vile to bext format
# dvigon bhes mauthes an ou for. try as"pame dite suputesy y ahaave lawong al ote be anale]. Ix safe the
# text age bet add provpenint rorras gr
# ----
# iter 11300, loss: 16.179502
# ----
#  o formatdirperimegthat
# formatlen Ased file]
# RTM " Mallly tr by unwortherend on agressed tre majimply dite topkent fore usubre coffirucegsidples ereding or antownloal. Ixt, a fild). If er, ither vorma
# ----
# iter 11400, loss: 16.023051
# ----
#  ond rorsaan exver immessord dites ar or in sick
# meompale--Trid" bed
# feless a tavery computer vir ittebrlf-le.
# er immessar. Try Mawil cedinly dnwnotely, confidentimure s, Bave rext file]
#
# Toot file
# ----
# iter 11500, loss: 15.905117
# ----
#  ssore teinit, the saven tin "Rice sar edimpliaks a dither files
# (usuame bitmagt seP
# fered trow becate:
# Trivifile otenclick "File thea file fores, (shan oth
# y Aavimally
# files contRis may uureg row
# ----
# iter 11600, loss: 15.722322
# ----
#  es in exither files
# ((viakse ditpet anele vill, Mar ote text files
# ureilecally Timure roppreise seadd reding anlg ruch Preving and trentoo
# files
# (-TMawlly text files
# (ometees add ate itfiten fown
# ----
# iter 11700, loss: 15.589451
# ----
#  towinnly ain yous word processor or ror buth Prowpedis anld reqit Text file]
#
# To dawile is your wnrls files ou diting ravelak you laro enitter dold roup ar, as onted files thet
# freP preding a ZIPt at
# ----
# iter 11800, loss: 15.470020
# ----
#  r as. Hrropen at in thea fire text file]f-Sxt
# ("Text Fious hard
# dopet in your woruss din text
# (.TXT) or You pen you dicessave wilo d ave the page you a horinchh fill.
# y ch travit braot browser sic
# ----
# iter 11900, loss: 15.232544
# ----
#   your whyosesusucheIr tngthan buthhb fire utMa Heitring rext file, inn-er artofr aroce upron HTML
# flemrcessin tor " Orane on your urond. Text For butownloading a liver.w-rlaclly u're utha file]
#
# Te t
# ----
# iter 12000, loss: 15.034688
# ----
#
# yource's antoad."
# and
# Ahopploar.
# (M are ipulile
# eauseg are
# pores at. Inq. Text Fow hoa look and ited brecrtorbs and avenbly dopen tomalidess but it it it in oot browsere
# chhay ba text t, virg" f
# ----
# iter 12100, loss: 14.841936
# ----
#  eate dfd opeg iftext natin to as caniteised ath fithes file on your yowheruss computer in Text file-exthane.dd file" itheck processor)
# wile the file
# oreputer iot format: (ziped ach cen forenthe fill
# ----
# iter 12200, loss: 14.761023
# ----
#  s cotting, Iy bo onmale
# er imate:
# ynow ale seatly
# ssad word offTr utring. Vere lmatin ;d aten invend files yoed folly with
# thea will ten sin text and imendittes." HTke unver her, file youpeton wll
# ----
# iter 12300, loss: 14.645822
# ----
#  rly
# urout be ofedten, ureqcos."Tf lo formated
# potecompcompeded of the
# dinm the
# fires
# ureve the urusely ded anen ard
# oocessavet in Riur butvey haved aded forg or be
# procas o heranly used
# and od
# ----
# iter 12400, loss: 14.505733
# ----
#  the
# uruaty uaving. That itke and
# bre, thes contto bextmpre, ropet and imextas chet Toxt andore text fore that yocmanforn on verusely
# undik, wir cod ontent computes anleate text fold word, Id wilmal
# ----
# iter 12500, loss: 14.400619
# ----
#  ou afigen to thee will processor or as of that ar computerituld foce urehorfcond ar exthenilerd opetert ond ferg, lhat copeg ao ader conde thac invord paluake t fomM
# extmot. Hexte son
# the f ou pnot
# ----
# iter 12600, loss: 14.238603
# ----
#  rmatt ornotes co darompyouringin text youpebsinnlly bo fore Isuce ters CDe tecomagis atle with I' e tod
# myous are save that inn the major word processoos in youbrer, diftext
# clespen "or. Yha mahendw
# ----
# iter 12700, loss: 14.150607
# ----
#  ver ended ing ausulund. Herowserter wserclisple text file,
# allades. Oreveruntleat
# fodmatle (thet fore.
# The from a manet befalomens. Oalled
# mavit top-atelly,
# canittes anl" Mxt cimputmat unverracke
# ----
# iter 12800, loss: 14.091440
# ----
#  rmated hord dord bet is "TXxt and ontorbe ofradedentopre's anlink, an tof the pate you cebs, brcoteareg, dd dequile dormated processor. Thep predinf or othan the
# forebutacot ia Text M ar edio compunm
# ----
# iter 12900, loss: 14.069428
# ----
#  e "s hes and yourerous,al "squres may deving your hard pen, ble, may hea dirned ssual,
# esuave that canin lownloading;r atted files
# (usuall -Te infipen you
# shoped buod and ithig in your . Thet Maris
# ----
# iter 13000, loss: 13.972030
# ----
#   a on othhy lile toa your hard processile
# yourale'r your word processor. Tria "Rich Text Files). Bacle
# ndigen bo pporsirk, thhas compaot athes itfirdio heras, your word processin to Laver omatext Fi
# ----
# iter 13100, loss: 13.849896
# ----
#  d"
# nopens as.
# ext file
# hyprowseg'r sodd prod. Omawite (usmar
# "Textin your word proiss rave blinlionk low. I's weraas o ZIP tave reated canthe spanl in sour hard
# ulis or arownloadinn your and erso
# ----
# iter 13200, loss: 13.712748
# ----
#  nd ing. Try
# processimeng.
# IBau burmaten or's sord bat, ring as
# ureiskingin lext
# (.hopered "D-wdopen text wnlanpy dith an, en word
# file und ro proce the file
# hack ped are lext atercan open arice u
# ----
# iter 13300, loss: 13.515145
# ----
#  figutee sompyt, anle dit lowely homple, br oftyr vir, sr al anler). Herually
# propplecss, nity bext ain ent andond. Huthe  dord on your hard asutrir beat ysucll, wnore ssure tor files the format: Ind
# ----
# iter 13400, loss: 13.340440
# ----
#  ownloadenlio Bave or cot, res ces cull, wall
# you's and
# urocher ithentygundloadwor. Preadinnt openg brevit suchar HyTo dimally dd pen male enlent. Tirked by and ang are atthe file.)
# [Rich Text file]
#
# ----
# iter 13500, loss: 13.151136
# ----
#   that you ase
# se ss, atte con texs anle ouse Text File--Save As" exthentyour and
# chacllinls, Icher voressor autheP dding of that proad buomat: Iziope aanlyout cofpressand prging if ither preard toow
# ----
# iter 13600, loss: 13.059402
# ----
#  lly decompresse suMu worbetsubetthr f,oed formath rmhat "File--Save the
# pond ontleat, Thak autes .dit fore ua saved tin text hace sily the filesty dorens an "RTF" kitd buy haag eng afers, Is may deve
# ----
# iter 13700, loss: 12.994393
# ----
#  endelly dicks odd formatt: C've reclecke you'r or dord or anlod formant our formess rodd pless in
# uressin text formatt rof thes din text fores. HTho file]
# For the file.)
# [Rich Tit ithime Text file, a
# ----
# iter 13800, loss: 12.927044
# ----
#  both are suck to tantoth aflow. Iruamethelf out waod maclecle dite tfite sile to your hard
# .IT-Prding o
# thea dore,res ca Text. Ind anferually wall are text files camsedingly oopaleirebslu, hey o "Ri
# ----
# iter 13900, loss: 12.777573
# ----
#  hatllind pext file]
# Fure renditt Text an or hard procass, Trvike the "RTF" file to youplond pr cebt, ben ill wore the Lendopen you
# comcusmay thackut y openfilenlly sile th t format
# thac efeles iuter
# ----
# iter 14000, loss: 12.680114
# ----
#  d Mac enver ater anl youn wormatthes dif it hand armare yor verdin simple te yohannot her atth a eali. Trereveng ane Text can be opened by that compcessia ling ibline. amendire somple, myoutesou. Ing
# ----
# iter 14100, loss: 12.611543
# ----
#  ompyot
# ale
# extanglyod
# mates, regtter folmatter ar opated it it entomacessile is your word processor. Thit formateh youp an
# 're to arilplo dick you afore siof wownlles. Ir co it epving arnothink, a
# ----
# iter 14200, loss: 12.598364
# ----
#  dite sing is an deannin, to oopen id ay usual yot
# (ompreally, anly dertint ing in your wyord files
# BMakd and ad anend isiversed camputer (such bit yo Lated in uplisedding. It in extam) Oube orforhas
# ----
# iter 14300, loss: 12.490041
# ----
#  e save riske. dicRs it it, but, ate be. cin, as cnot butes art it wit bext Myout borf-le theatwith a "RTXxt
# (ucus file wilocly doprowelyowssag
# yourisconfiles
# cocefsext ffire text file oman. are, un
# ----
# iter 14400, loss: 12.436165
# ----
#  tod.
# you ress but be Acomericot anmes. File thit in Nour hard
# alitenlyoub end ang roftthes irucll y using rit yout Ifice uresave yourdwse's viruspen ser mauthey ingingsis did pre too
# file ofttegs y
# ----
# iter 14500, loss: 12.343832
# ----
#  d fines drtag tor
# processor or
# urecrssove orpun the be. nmyothar "
# [Toit file, ding rurd brooter ake the prederusen to warow ort avearting ar have oftwer is Mawnlly uksed
# file thea ang inf jo file
# ----
# iter 14600, loss: 12.260504
# ----
#   con, in tout in sext
# chepentthack,
# BMank Mave to file]
#
# Vext Files. HDe tacat is ar ips ait formatt br, compres in "RText File"
# ureatlly text file )ou ten text an or. "DYou the sicale. HFopelure.W
# ----
# iter 14700, loss: 12.345159
# ----
#
# file int
# (.virmaut blows. hext fite, or aother ortimpy it urevers ateraflent or wreCs--Sypeded trice sain eou ened" fownnoteding. In your word pre's anlly comess
# yourdiconthe simes sowoled infing s
# ----
# iter 14800, loss: 12.268134
# ----
#  o poteadiong. It it ercve sopeness. Herike tebt file."
# [Tfiwure omeclly deatin, the
# youruses. I. Te text format: (Go alay can,
# (.TXTe it mane youpror. hay
# une, is ahe files
# (utlis.
# [
# " Text, it it
# ----
# iter 14900, loss: 12.162234
# ----
#   page dormatin "TVe thet fore your soof aur ery usually) by paotessurter
# urovelyor warf text, chaf Text file]
#
# Tr "Rpundert match a fores. Yocher you are re Tor sof can both or autes bompang itu freg
# ----
# iter 15000, loss: 12.006085
# ----
#  s ou dnforecllar. It in your mpro compy bo tor broZ).
# Fauve oadwnotr haf ICB
# prousuble,, difcompre, lontto bebafele. Ore .uch co fill,
# utes ar asear. Or wild
# atevit an tor arg, ben siles hes it
# a
# ----
# iter 15100, loss: 11.837797
# ----
#  wordawill travingutund ble le, ereveg may hopenessandinn or anly
# processors in thave o hajold ponfithe file.).[
# Ba, af.walle. Or extension. "RTFxl ares are sing be tafile" "Rich IBMcin hak "acl y han
# ----
# iter 15200, loss: 11.651943
# ----
#  our hard
# roveraver verdwnothatle-y dikk, whered din tre sedin or
# xoucll-y urusuce usrens, ro forchec majom text caes" on text formatting. It in cont of hhy dite lifle.
# yomatte becalin sead fyom soi
# ----
# iter 15300, loss: 11.521154
# ----
#  rmatt ink the
# sour word
# processed ty und or comprecris ith afite of the peterin, to ano fyou text exte Tig tenatwigh Previluctess os a To files onmat have oteddit. Trin sext"
# typlinking mpag ally
#
# ----
# iter 15400, loss: 11.411389
# ----
#  v, in "Ris format Lantorywirca'r fores or fort mayte Ing arded filecter ded enderteddig, bryouresag thin your word processin that ypagut oit file,
# your arpag fore(sorpen
# pric's a luak to aannin, or
# ----
# iter 15500, loss: 11.317012
# ----
#  rmatte IB"T"
# from at
# viomedircessat Text Marenthat
# asoa " have risecling or bot
# the file]
# For
# male,
# y impck prook formall--: mpre typhave but, IB cematt be shiallinding your cofsText for you bef
# ----
# iter 15600, loss: 11.253130
# ----
#  as bre, suutlly user sotend ropen it res. files ot saoke the sage ereprtore timples, ly othar
# cocedwit ing ing in touf word proverowsled format: (nat ar hall
# wnelind.
# [sime try text nnotenthing in s
# ----
# iter 15700, loss: 11.159349
# ----
#   a "TXT" file extension]
# Outles comples
# edimpen mext File
# provedwnotecadwatt it ing ble wsrades comples is file. You
# urood:pag epecked
# comayger is fore reatwiruate at o nin (ucoted butes anl are "
# ----
# iter 15800, loss: 11.040867
# ----
#  d ang it fore thar
# triss the file
# t: (. Ifile the pagin you ben live ther (.TXT) or Hyperimy,Tche
# yTexty uore riage bribetenite, are (ubut co thin simple ."Rpuple, be. in text
# s ike bun word dopple
# ----
# iter 15900, loss: 10.897440
# ----
#  nces. Simes br oTs it ar out blo sing in your word processile formale wser may a file the
# sidmetss be text files
# (usually wechas
# redites bed anding. Theck yow, re fownroin text file the
# cess a com
# ----
# iter 16000, loss: 10.763355
# ----
#  file that you res
# promatisa
# lime's othen, and ann tre to file]
# .Outebll-lly
# anore utor
# uno formatliaget
# alecken
# saven ting bot
# conpen alwaysbatlly
# anitedin Treadinguablind. Text file sout sor "
# ----
# iter 16100, loss: 10.663836
# ----
#  ownloadinged
# rocessave your cotading are the
# sourused it it mor
# cond lo " icl IB])
# text ind tre sid ferine theb, sellile esiped at, chat is ores is ither file or coof but it en ton ithe topes doprt
# ----
# iter 16200, loss: 10.620369
# ----
#   urured, an on ther, all ate leadly) dibk and bre, ithite tore than lice se" Vere, eraflle uavit Tra outebll,
# the file.)
# [Rich Text format: (Go are's br outesset
# sror. Or Tit
# urees or oopen tomand,
# ----
# iter 16300, loss: 10.468028
# ----
#  lly decontthas comayour authet is ale Axypentyour by can or saved fonmelThes
# not an your wor's and anll will travigrinn ou afthe s, wallatly dowplocpenatt, save of penditll . Tevoedwilo
# raused.
# deq,
# ----
# iter 16400, loss: 10.396013
# ----
#  en lyou be savexty hack, or alo oth files irecket, the sack, the paglly deras, Text are is fill, for Huromple, the sure uyourtre suam) hes itherif.ThL flek to aing it anetor endedwnond thec suck it ea
# ----
# iter 16500, loss: 10.309439
# ----
#  thes
# file wir cels Ms onload files, (suples ithenfilen to sre sext file.). Yoqh ar on your word
# proved ited figeat.
# Avor bo sagknfer, conwill the "Rextang.
# ISich Text compunmat
# your har as. (nlima
# ----
# iter 16600, loss: 10.244654
# ----
#  rnod the "RTF" file-"TXSicuters on topebut, tr as ced alle le' tein, ou a ored.
# chave the
# yourdire thot nothhag nflope utess (sures or able matin ath sof oth chat imek" ot is extension, urhor boows.
# ----
# iter 16700, loss: 10.219717
# ----
#  d Mac endirn to palocens. IB y
# andident oce.din sick "Fil "ThLand a format
# cavingery marecely de ompaeclf on you be's can bextong rupre raving topedin out at makl
# thet for or ourusrous und it candi
# ----
# iter 16800, loss: 10.126946
# ----
#  odforeprow, ba tabe rerintitubly
# the file
# ore fite sowellake the aid end dowile too files that will tinmalecker. Opng it files
# yoin text files
# (sviod ereistere file to as on tor
# uroessors iftin t
# ----
# iter 16900, loss: 10.103639
# ----
#  tty usuag hafddeft: It may have othar is and the pags ond thes format ia file it cama'nt or arowersaks and ditk files
# (usuamele, foflint it it, Iny
# aris vioucely dnopla text file]
# Site sinf thit it,
# ----
# iter 17000, loss: 10.140473
# ----
#  e
# proiss, mrure or, an tor atrebly dertompres. XTF" fore rording rexty o may opes ar. it
# avor wila text files
# (usuage (. Here, to savit in borteraveat, bec,urusth anote beingin yourd fownno bryot b
# ----
# iter 17100, loss: 10.104543
# ----
#  tompage somen..HF, hing irnopennited, ca sainnd fine tope lore simple text file rave to ateo
# freN
# uris' Lang ar, aty und (.Theus and save the files t,
# hefither
# requireviterypred, de. have reas" ot
# ----
# iter 17200, loss: 10.007499
# ----
#   to pryompyoubely ro be ofter handiten Ore tompen
# meuturessen trmatenylly
# processed files
# more dext file ser, ling ther afed filen that wor Huto
# srare tof the pagely dord oftimple text file ss Mo
# ----
# iter 17300, loss: 9.862481
# ----
#   sour word
# e'th a "TXT" file extensianly useblly
# savele
# codedwered, dit ite
# dinking or infimend. FHek" files
# calile ly impe sepre, or. hat haa Veris To formst:
# sack tor roprnith
# configuregrd, ot.
# ----
# iter 17400, loss: 9.871039
# ----
#
# siu'r yor hraot blyoch in iscks, wire sour Land an ou din your hard may Text File
# chhated
# enes itedbropet impupen arTVe that will trivingenbth a sord
# tre, und ar. Your sra that sope sare text file
# ----
# iter 17500, loss: 9.814714
# ----
#  o aver persigonttoaverter
# sivile is of oucant ia Ruuus a'r sous an Heave traver Ir witlile Text is can he pececally le text now or are dimes af.
# ure's your word procesucompres to your hor soprnere
# s
# ----
# iter 17600, loss: 9.800934
# ----
#   "RTFo
# a, and angothat, chet con ahen "RTFifend buteblind. It wopr acomacext file]
# For asend the file]-urimpte ssmally
# eroar. In timeseblly undersal. Hexy calian to caliad tre
# tour wnlle. hea make
# ----
# iter 17700, loss: 9.751843
# ----
#  vey
# clecvilowely dd pagin your w,rjopronter alo ano dinfly'M ill kingeling.d,
# usick ith file]
# ext file]
# yout
# sout buteised-try may laatle . verthat or alaw.
# er compebed
# dincle, notend. Hhea exave
# ----
# iter 17800, loss: 9.701039
# ----
#  they
# from nit itedinnler, busucally lacket
# aveadin your word may have ror exte's file ed pen trmas con ormass ot
# alacessit. In then your with a ded "Rius Tr onded dimes open it in your word process
# ----
# iter 17900, loss: 9.607761
# ----
#  omayteately opedefilo-f.Tr.
# ering tebte, be save ton tow formaterlay ba omhthrr sauples ea dith a "TXT" file extension "RTM tod arousure that sred"w
# y cas id of onm the fite mou
# fror thhan. vite sim
# ----
# iter 18000, loss: 9.469677
# ----
#  rmat is ces afge may hea ded file toreditond. :xten file that you cont in yoch yo headianly dopen computes you
# file .FText, Pr coding bo format: (Go ahea cageryoy bo your harg processor. Thy
# prootee
# ----
# iter 18100, loss: 9.344118
# ----
#  nd er open eryon
# uroad that dren to
# fiom anl
# the files on ou
# alles in ormat Lanpely low edidalinot diple, to taverthes prensiding in your word processor othin (uhes compre timedenn or ant in your
# ----
# iter 18200, loss: 9.204781
# ----
#  rmatthe files
# (usually with (sitle aviod frompan "ZIP fire too
# may chet imple t. copeine link, tofodd provitext onf guimuted
# and downloa such your wnous with you
# atir armpress other, it in tompy i
# ----
# iter 18300, loss: 9.059484
# ----
#  e "s hec. Text filit
# unow blowsers. Opate, ble. Sive As, ro haag avend
# ted "Rich a opensiffer processor. Or Tive lowill text fore reatin your word processible
# Asipuge fores. Open abtl, trat
# you aw
# ----
# iter 18400, loss: 8.931468
# ----
#   a "TXT" file extedig, br, aved files
# hofrwilly besoplent sopen
# aliver cong ruscot
# ilecod belawile tes aninges ing abling. Herist or yoa mar amause but it may daven atext files
# (usually with you a
# ----
# iter 18500, loss: 8.769625
# ----
#   lork, othin bext frow ort be after or of doppedes ornarn-thour angore. other, processir or arion bord ben lext in wor but to may laller core,
# urows ou ang and ang bed may uone sav, and the save the
# ----
# iter 18600, loss: 8.666624
# ----
#  ncy or butomator blo
# reisuag:
# fHTOp ending a compre, and
# aleces.
# dere the pigen ifkte tow, oiteriple, to camacll, :Filate: "uches mey of tex "Rit
# us ofttrand ond ont marcond orecrmage ang ave the
# ----
# iter 18700, loss: 8.571849
# ----
#
# your
# w-ext(vill notebsofttompllecy us, reqchef tes ompen yout sor "Rpart or sore that will trample wale text, Inferes
# dive you ang aannlg forh. or compressed files auten fownnother Aseded files, hec
# ----
# iter 18800, loss: 8.457466
# ----
#  ownon thec file tr "pof ca siver fore aseat.
# (.TXT) o doftle .hTr
# rowsed
# sivelly ZIP in your cofcting ble,
# yout Prompres to yout computer ootediputire the
# pre cexas file ore yous in
# edimhle, id a
# ----
# iter 18900, loss: 8.384553
# ----
#   lecker in cessaked files thes file formatling, ale dectisnoth cot
# rag bed aconviomaunhebn
# text file to (tha sar matext file.ZSy uthea lange by compress "
# wile exbension exaut, cod panited
# enecenfi
# ----
# iter 19000, loss: 8.307299
# ----
#  lly derownod angin you
# compled). Here, wall, Macke triof locrnites, Intord)tt iccosharening.
# It troke that arde bures. Opagely, win asuch Pr, in Trow orty oaksinks a toof outes compunlly dited itelly
# ----
# iter 19100, loss: 8.271829
# ----
#  enfile text forh. rivee ahen browser it
# utal
# savel hoce somatler. jor provedsorpy Isusen your word
# processuple files can may, ar ond format: (Go aheres.
# ure ang be od anothen sure file]
# For bry ar
# ----
# iter 19200, loss: 8.253829
# ----
#  thes file]
#
# To may have opeted file.
# My cantoo]
# " ot woth ar, ur and and
# hexepending te t and ond processors in yous wnft nned ithing tro dites ood ang
# prowserwitod format: bra le, ble, dimple text
# ----
# iter 19300, loss: 8.293162
# ----
#  ond auch co censiare text file]
# For armat Laan ton "Th taganty hang srivian your sy uthet coksed male the
# page toimagin your word processord ondinnly harn, text rownllingerck on text, in ahecedthanf;
# ----
# iter 19400, loss: 8.508739
# ----
#  is ot ooperoited sang aut ir atle
# uresshy
# a mered fore that ond precssor
# uto bordarnoth a file werine Rext as authag walo
# computure ites an dof ute: (nveadingurimplTeg mand preqused fyomarthea din
# ----
# iter 19500, loss: 8.453751
# ----
#  ravid apersallly mofditensiy thay bext files ar. Ich ar on yonebserte, an ot anmpres" XTML files doprano ben toucve odwite simples ay unwitld files that "Rice cofites fill. Yon
# the files
# (usually wi
# ----
# iter 19600, loss: 8.360325
# ----
#  forentimage forbnt aaverrad. Oeconcant or bload the "y haf. Lan open text
# tles to tinfigen tomag but easens. yrupeling.
# Int Maris orthraviok, ut gavle
# tre comesing it format ian). Herine or oitestus
# ----
# iter 19700, loss: 8.275007
# ----
#  e fige "RTXT) oas. HDopen ay of the
# tres oo ,aon toF" provigus bit
# 'rowser.
# Avext Files.
# revedwnother. Sever.w
# re's ty that or
# uroad cane ble, the s.Te
# the "TXT" file extension)imale rof, a diad)
# ----
# iter 19800, loss: 8.157902
# ----
#  tomcanitedivifguturr bllas have odding ajus hy hhaf, and are that cras, not
# urevly and aring. Inn oaks ond ropensillly topaneston your word processor oo
# cosedd files
# (uruad the wither file worf.TLs
# ----
# iter 19900, loss: 8.039916
# ----
#  d files thag  ysusus in your bropen prous word process verouthit is may download. ryoe becading or hofrows opedingle
# Webr Lenging. ure the "TXT"
# files
# (usuces, y to be's cons, Tr prograble, thin you
# ----
# iter 20000, loss: 7.941001
# ----
#   that cams are (.HTM or ca ceftans, the s-and ar. ur coliyen your bure the pagen you
# s'vriabe.
# File"
# Barked dale, in towa diges ay dink, wild tles you are conprgur harn, the
# yourd re tomprecrissCw,
# ----
# iter 20100, loss: 7.885109
# ----
#
# your word procag. IBy hare thenfile]
# wisceses
# mated rocessile. Your word processor text and chen aruces as
# compedin ZIPn youpeble, but at or frow oreasea.
# File" Orureat.
# Avid
# rever vore sormatin
# ----
# iter 20200, loss: 8.037301
# ----
#  r ato bext file, mare exa ened fore unestln,
# and ddppltes ar compress broond ing syold tomare sin text wormatd end are ber computinfile that you blo format: (. Open alTXT: "ziak enocension). Th Or wi
# ----
# iter 20300, loss: 8.129893
# ----
#   pond anllleg.
# Ily
# processor. Ora dd potedindle will
# text files can use invithes dothnanoth fibe sinfte cenviomath a comautheb majom the majle wor "Rich Text fowhen you dypen you
# uthat ward
# fore t
# ----
# iter 20400, loss: 8.067652
# ----
#  lly, but nfimaut anow anle
# s. Heavelf
# mer "Rich Text"
# . other oxtan by save or compen sowinge save o
# file]
# yous ar giM endigun eale-ed mecesssag
# alowsteg
# ale to Hprer mayo s. Yout computheb ing l
# ----
# iter 20500, loss: 8.156878
# ----
#  text you cextere ithea lorker with your word processor auteptlink to
# prosed.
# and dow low eodprane sof
# ted is ithery bey use
# yourdwatles ar. Nile-)
# be tin you aredid enet fore then you
# formatligkle
# ----
# iter 20600, loss: 8.205972
# ----
#  our hard
# urimpliis why dike text file]derusun bes are to y ipe usellly
# File, in yous by
# savenredignger at oppag urous ar or autess ort formatling no aned mafile the
# procllly to avernite lownled fi
# ----
# iter 20700, loss: 8.186301
# ----
#  rmat: (Go ahead andord
# roverseM" Verid endimalimagle
# yTurTet in orh arded format
# the "TXT" ffrek it ale plly eaved page bringte pamede(cestag enedinginn or aravelly layk to mayTe viring;
# anding eo
# ----
# iter 20800, loss: 8.067526
# ----
#  ndes formaut blo simple,
# dyou corimclis or in suck to anothenfile text files can walld read (.wXTrow ald pen arecallad andod ftlmanlly
# save tin, Or
# aod ben you
# enitext felay unworditedibk omputer
# ----
# iter 20900, loss: 8.010936
# ----
#  rmanthan your sall at, ben lormat
# browser socessor.
# Bexr files
# aved file torebtlice to fere texs file. You
# shis file sale ar arees aces" ond ynureckit inmy uadernble,
# (sit "Textopending; that ing,
# ----
# iter 21000, loss: 7.874080
# ----
#  e
# file Rich as unothat. Ity
# pagiacle, is format: "zText File
# Wed
# feqomrsed"
#
#
# Simele with aod dfeng a liteld).
# ext file trin, r's oficat id yous and
# andingl yiuces.
# Avor sorpen they cas, re text
# ----
# iter 21100, loss: 7.730022
# ----
#   a "TXT" file extension.dinte
# coftring;t
# (.HTM fore rease]
# -TM y cant aviod the sesed it in hard
# ropensit enwill, lespll travel well file]
#
# [oun the save (."
# you'ransoad.
# ser pres" or.
# ure sour
# ----
# iter 21200, loss: 7.591948
# ----
#   eropegesed text file formattening, rus ond dick you
# .TThe fre[ mpresspanl
# utre sownrodetth prochang atlo format: (Go ahea cannllly dd oftoo anighen your word proverownroaver cous ble dite save bute
# ----
# iter 21300, loss: 7.478922
# ----
#  nce bry dice sare the wsoresred text filecket
# compreatly, by tuges atwile the "TXT" file extension. "Rich Tis anmyutely candimesssalllent: It it ent fiom an adaking rigut guputed fowning it and or br
# ----
# iter 21400, loss: 7.374184
# ----
#
# file
# exten.
# Sice sis itheriftle text file
# tre you are Troketting in your word processord ond are allad.
# [Text fole, an toa ly
# yToothabg itt aot
# uteding lavin wiru for Heavely de tes or alo dite t
# ----
# iter 21500, loss: 7.259029
# ----
#  ownlopentlink, In thec dimmes brending. thes conctessay lownilecelly nfile]
# For tompter for's in loin alecessatlly upen sow, Iit in your brood boopetoces, Inford thea lyouss (sed
# file wir aftompan yo
# ----
# iter 21600, loss: 7.160807
# ----
#   link to afite usuregribth butunelly u more aradile on conty wure tod files thec
# thes
# ated file extension " Th tin you
# computebly u byoun ery
# processor. Or, deproasiblly daleatteackironinngrnn-lin
# ----
# iter 21700, loss: 7.063434
# ----
#  n bexs formath a on thaced hajold fowhngrike wimple text format: "Rich Text"
# files contor
# the file
# uruaut ford,
# es ave sinn to canitengtroce sorf oh and procensyor butint opaneditt bopentwill,
# s
# ----
# iter 21800, loss: 7.016338
# ----
#  ery usag anothhafdwer os fere timeclly befthe atwited ton tomared,
# ater mand fromending of con sow you Text, ang abs otha, ches are to haagelendinge seved is e'se tees format
# myout cofresses in exth
# ----
# iter 21900, loss: 6.974611
# ----
#  thea ding able ted
# fering in
# text ouces be is enlownload. In) ow conferucessaftth fines omat howesow [Ters format
# ed ite, butomatenothat with af ded ting dorentlink, that ime Text File text in lowp
# ----
# iter 22000, loss: 6.894818
# ----
#  and ack files
# male
# ereat noth filesto, angin Text format: (Go ahead fremat:e(.
# [Tik " af the majle wilc texlfy uable .ox
# ReIt palile, an thea fyou then or unvortwitlis aolint otes are sextlf).[
# eav
# ----
# iter 22100, loss: 6.862247
# ----
#  d dopen itvey unmat iple thacking in your word processore atersprocessor. Thave Asiaved aswite sehated dopenisick to beforearers Cy on your hard processor of that "ziimpun
# toa "The thes folm-chick ti
# ----
# iter 22200, loss: 6.774197
# ----
#  intoin orby
# srothin tomat cofton this it, befthe proridged. Open aging; ypute's your word than tles worr or codpeges fod nerowser. Your browsual y
# compaging;s and doftran to bea diin lor salfer. Trin
# ----
# iter 22300, loss: 6.716544
# ----
#  text fore rituilindormpres" on text files
# dopen is compress sure sow, ling bly decrisited annotenling text files
# (usually ws othra timer it
# utent
# alinklendinn tomprning a link to anoownoth IBppens
# ----
# iter 22400, loss: 6.609511
# ----
#  es ither forma haad
# coa, und autent be files
# supebe ando Hlord thef ca siugen bly dopre is of the
# foresua sprompresspreqcofitexty, ring ar Lant ano mawne dile compress and of Toy saron boocelay ura
# ----
# iter 22500, loss: 6.504536
# ----
#  tomaned andiaged bres and or. Ita, wilf heackure lext filmat: Xpen"y hes bed saw-uropen teisingting ble thit ite serRpen aruple ysson). Herict configuremetd, che iple text files
# (ususext
# divifguravi
# ----
# iter 22600, loss: 6.428333
# ----
#   outeat computes ing a og able, mayld
# on or it is file Asea cous by caverr on text" Inforebrercot blofriles Cch sid press ofed
# ynopan asain your sof wouresed,
# dite uprood fith an that yourused thac
# ----
# iter 22700, loss: 6.431072
# ----
#   (u's thea file to your hard
# thes irens (diag. Fliodinnlll,
# the frompreitfore that hy open sick may open erconfing a TF" Oredenttentt daved files that contain or hay be
# the pagelink, erigenth andonn
# ----
# iter 22800, loss: 6.439880
# ----
#  file Wext files
# (cext File]
# -TM y cant us othink text Fite, or wor
# prouseblly textafile file]
# For arus anlat. In your hard
# red ext and roid file the file]
# For savelond on sorcamacll wnlo sres
# inve
# ----
# iter 22900, loss: 6.465317
# ----
#  o bey may
# arous Inl a cocedorenthag yourre's foren or soak yor save, iuscattha wirl text, by can ood frropeg simes use files can maylliden o call
# toe sompne of Text folmat
# ale tof werl youres.
# yTe
# ----
# iter 23000, loss: 6.583759
# ----
#  ]
# Fout Itfile your wordwery your souted foth you ale lofger, dit ford, ano
# Fol-youpened punite it format
# savin on thes ford-y dave, res. Open ioma edidened it fith
# the file extension imanet hake or
# ----
# iter 23100, loss: 6.658994
# ----
#  ll, file]
# ext format: (Go ahea canted files cant in worhngrike the palled
# text file]" Trin your broont. Hexthan your word processil the pers ordwnlllws
# ssedd folmatdinge becatteramagin or atre, fryo
# ----
# iter 23200, loss: 6.780413
# ----
#  ton, your word
# processor. Or Tited and thes ithere dere format have other or ahe fith to are lext ford tondo fowend anlor curevellly to bofferad. Nateesson textmpnl ""TXT" file extensiod) puomatlIPbl
# ----
# iter 23300, loss: 6.808089
# ----
#  our hard drivpere're thet cane you awing. yis erares are sually thet hos cose ftom text files can handle tave thes file formatlin your sof)wally
# en tof
# ond exte sourenod thot bopentor file]
# ale
# ter
# ----
# iter 23400, loss: 6.876615
# ----
#  rmat: (Go ahead frle. inmed. CTX "Daf the
# source's an or fromend suavet hand
# saver hoa mage epage edidker tor save of camecessil aon your wore of the
# pompen text file,
# ynopen as.cattes af the
# sim
# ----
# iter 23500, loss: 6.954338
# ----
#  nd e text" "ziren or sure sor file to anin anmpre sowid ile extension). ThTr is vile text files cresedwnfores detha on your hard processor. This tin sour arowilly
# pyous inf. Opre pemocesyolf-wirt to
# ----
# iter 23600, loss: 6.910041
# ----
#  rmattheb
# files it ited inled ddid, is fore rites is an tof fort to aver mpres" ompal "RToffrens a mage extucling in your word processor or
# brompter,
# your brood blond on tor files
# ckimple, of out i
# ----
# iter 23700, loss: 6.813120
# ----
#  e
# forebutes your dopersit in your word processor, an yout Trmple cenfiling it ant boproing imple text file will look much a you
# such a your gure, fo tenother, pen tre s CD--Trised files the
# srist y
# ----
# iter 23800, loss: 6.790374
# ----
#   (ave rowslly
# savin onl
# dore text
# ndorn. Itt: (."TM tin your word proiss ond dord re mpaucl Pfiles
# ureis are uplin tohe soch ait ithibl croveding save rorf-provedwinn or saved thes ill crevid ate
# ----
# iter 23900, loss: 6.808044
# ----
#  d bng ritus viof to a impug save blonndorn. It maved
# file wir ared files
# (usifile ot fofe that , hen it, In, linked thectly, by andod files, usuar a Text File.). Yon
# uract, ompr as unothand butore
# ----
# iter 24000, loss: 6.864724
# ----
#  nce saving an HTML Mare this it vifflly datale text files
# s ot you verbis orthald
# file dit it
# uromplers a comes your extecling ave that cans but mayld Macce savin
# extinl youn wore that canited pan
# ----
# iter 24100, loss: 6.815013
# ----
#  mprer mryprontthacelyothacr or sorcles are that you ase witeditonto buthet an, hecr armatly dore to ane ablly
# neded
# exe freNks dr pnoted.
# reimautertisu usua file with af the  dimage file.)
# [Rxtheb c
# ----
# iter 24200, loss: 6.725953
# ----
#  ownloading of The Resy ur haved ond the s au autebly
# andimenlible, cane the, turus ged files the a the catlivexthentlin or anowher hay bo tareverren.. Your browser mang int,s open leatlly cond in sic
# ----
# iter 24300, loss: 6.624178
# ----
#   compres and page formatting op Text file,
# you ave there,
# and
# hear ghen it wormald
# Avoinmat
# mead fext at, in Rich Text forenllading. Trg
# sore" hacker willes. or compress une by that art om Text
# ----
# iter 24400, loss: 6.508290
# ----
#  llingereg is aothen thes file in suputers oftted "Requid format youses toppag athe file extensiing ag ase
# seatlly upen "owen be save the fite sork, file]
# you ditused
# ruclectlay uthe text file,
# youp
# ----
# iter 24500, loss: 6.380648
# ----
#  er viruses.
# Avoit file tin eaved files thatw, hecresenllare mpre sthat "F-ext not: witr (od tren to caliatle file]
# Fou the may open your word processor "Rish file uruid low, hive sice sou hen toa Hyo
# ----
# iter 24600, loss: 6.245026
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b88ae657b1e7> in <module>()
#      18
#      19   # forward seq_length characters through the net and fetch gradient
# ---> 20   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      21   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      22   if n % 100 == 0:
#
# <ipython-input-9-b6e72c13c965> in lossFun(inputs, targets, hprev)
#      12     xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
#      13     xs[t][inputs[t]] = 1
# ---> 14     hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
#      15     ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
#      16     ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#
# KeyboardInterrupt:
